# %% [markdown]
# # Import libraries

# %%
import FileReader as f
import pandas as pd
import Regression as r
from SQL import PersistenceUtil
import statsmodels.api as sm
from statsmodels.nonparametric.kernel_regression import KernelReg
import time
import Visualisation as visual

import numpy as np

class FilterVisualizer(visual.Visualizer):
    def additional_elements(self, index, min_y):
        pass

def convolution(y, length, mode="same"):
    y2 = np.ones(length)/length
    #zeros = np.zeros(len(y)-length)
    #y2 = np.concatenate((ones, zeros), axis=0)
    y = np.convolve(y, y2, mode=mode)
    
    return y

def regression(y):
    kr = KernelReg(y,y.index,'c')
    y, y_std = kr.fit(y.index)

    return y

def hodrick_prescott(y):
    cycle, trend = sm.tsa.filters.hpfilter(y, 1600)

    return cycle, trend

def wrangling(df_train, df_ideal, title="Training Data", plot=False):
    df_train.index.names = ['x']
    df_ideal.index.names = ['x']
    regression = r.Regression(df_ideal)
    df_train_mse = df_train.apply(regression.mse)
    df_result = regression.min_value(df_train_mse, df_train)
    chosen_ideal = df_ideal[df_result.min_y.tolist()]

    if plot:
        visual.PlotFactory.show(title, df_train, df_result, chosen_ideal)

    return df_result

def main():
    pu = PersistenceUtil()
    df_train = pu.read_df("train").set_index("X");
    df_ideal = pu.read_df("ideal").set_index("X");

    ####################
    # Convolution
    ####################
    df_train_convolve = df_train.copy()
    support_len = 12
    start = time.time()
    df_train_convolve = df_train_convolve.apply(lambda y: convolution(y, support_len))
    print("Convolution", time.time() - start)

    i = int(support_len/2)

    df_train_convolve = df_train_convolve.iloc[i:-i]

    df_result = wrangling(df_train, df_ideal)
    df_ideal_convolve = df_ideal.iloc[i:-i]
    df_result_convolve = wrangling(df_train_convolve, df_ideal_convolve, title="Convolution", plot=True)


    ####################
    # Regression
    ####################
    df_train_regression = df_train.copy()
    start = time.time()
    df_train_regression = df_train_regression.apply(regression)
    print("Regression", time.time() - start)
    df_result_regression = wrangling(df_train_regression, df_ideal, title="Regression", plot=True)



    ####################
    # Hodrick-Prescott
    ####################
    df_train_hp = df_train.copy()
    start = time.time()
    df_train_hp_trend = df_train_hp.apply(lambda y: hodrick_prescott(y)[1])
    print("Hodrick-Prescott", time.time() - start)


    #df_ideal_hp = df_ideal_hp.dropna(axis=1, how='all')
    #df_ideal_hp = df_ideal_hp.fillna(0)
    #print("\ndf_ideal_hp\n", df_ideal_hp)

    df_result_hp = wrangling(df_train_hp_trend, df_ideal, title="Hodrick-Prescott", plot=True)
    #df_ideal_hp = df_ideal[df_result.min_y]
    #df_result_hp2 = wrangling(df_train_hp_trend, df_ideal_hp, plot=False)

    start = time.time()
    df_ideal_hp_trend = df_ideal.apply(lambda y: hodrick_prescott(y)[1])
    df_result_hp_trend = wrangling(df_train_hp_trend, df_ideal_hp_trend, \
                                   title="Hodrick-Prescott (Ideal Trend)", plot=True)
    print("Hodrick-Prescott", time.time() - start)

    

#    reg = r.Regression(df_ideal_hp)
#    df_train_mse = df_train.apply(regression.mse)
#    df_result = regression.min_value(df_train_mse, df_train)

#    print(reg.min_value(df_train_hp))
#    print("\ndf_train_hp\n", df_train_hp)

    #df_result_hp = wrangling(df_train_hp, df_ideal_hp, plot=False)
    #visual.PlotFactory.show(title, df_train_hp, df_result_hp, df_ideal_hp[df_result.min_y])

    print(df_result)
    print("\ndf_result_convolve\n", df_result_convolve)
    print("\ndf_result_regression\n", df_result_regression)
    print("\ndf_result_hp\n", df_result_hp)
    print("\ndf_result_hp_trend\n", df_result_hp_trend)

    print("Done")

if __name__ == '__main__':
    main()
# Out:
# Convolution 0.001995086669921875
# Regression 13.180055141448975
# Hodrick-Prescott 0.014402627944946289
# Hodrick-Prescott 0.8927037715911865
#                     min_value             min_y       mean      variance  \
# y
# Y1 (training func)   0.082807   Y5 (ideal func)  -9.965925  5.687016e-01
# Y2 (training func)   0.083911  Y25 (ideal func) -54.979219  8.249526e+07
# Y3 (training func)   0.081011  Y50 (ideal func)   0.058217  4.551632e-01
# Y4 (training func)   0.085307  Y38 (ideal func)  -0.061195  1.075115e+00
#
#                     max_deviation
# y
# Y1 (training func)       0.704151
# Y2 (training func)       0.705693
# Y3 (training func)       0.703165
# Y4 (training func)       0.703572
#
# df_result_convolve
#                        min_value             min_y        mean      variance  \
# y
# Y1 (training func)     0.011598   Y5 (ideal func)   -9.967361  4.396278e-01
# Y2 (training func)  5909.425754  Y25 (ideal func) -107.996631  6.892391e+07
# Y3 (training func)     0.007604  Y50 (ideal func)    0.042335  3.399197e-01
# Y4 (training func)     0.014243  Y38 (ideal func)   -0.039583  8.853422e-01
#
#                     max_deviation
# y
# Y1 (training func)       0.504715
# Y2 (training func)     269.462249
# Y3 (training func)       0.332963
# Y4 (training func)       0.404135
#
# df_result_regression
#                      min_value             min_y       mean      variance  \
# y
# Y1 (training func)   0.010194   Y5 (ideal func)  -9.965691  4.440935e-01
# Y2 (training func)   0.082066  Y25 (ideal func) -54.979266  8.249542e+07
# Y3 (training func)   0.008004  Y50 (ideal func)   0.056950  3.395293e-01
# Y4 (training func)   0.014735  Y38 (ideal func)  -0.060137  9.479382e-01
#
#                     max_deviation
# y
# Y1 (training func)       0.447890
# Y2 (training func)       0.716693
# Y3 (training func)       0.333178
# Y4 (training func)       0.414962
#
# df_result_hp
#                       min_value             min_y       mean      variance  \
# y
# Y1 (training func)    0.009603   Y5 (ideal func)  -9.965925  4.102777e-01
# Y2 (training func)  118.537484  Y25 (ideal func) -54.979219  8.248771e+07
# Y3 (training func)    0.008027  Y50 (ideal func)   0.058217  3.145685e-01
# Y4 (training func)    0.016338  Y38 (ideal func)  -0.061195  8.348710e-01
#
#                     max_deviation
# y
# Y1 (training func)       0.395714
# Y2 (training func)     136.414359
# Y3 (training func)       0.353679
# Y4 (training func)       0.718150
#
# df_result_hp_trend
#                      min_value             min_y       mean      variance  \
# y
# Y1 (training func)   0.005276   Y5 (ideal func)  -9.965925  4.102777e-01
# Y2 (training func)   0.003578  Y25 (ideal func) -54.979219  8.248771e+07
# Y3 (training func)   0.002651  Y50 (ideal func)   0.058217  3.145685e-01
# Y4 (training func)   0.004911  Y38 (ideal func)  -0.061195  8.348710e-01
#
#                     max_deviation
# y
# Y1 (training func)       0.269872
# Y2 (training func)       0.233271
# Y3 (training func)       0.272189
# Y4 (training func)       0.251488
# Done
